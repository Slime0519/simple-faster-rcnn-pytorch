# %%
# %load_ext autoreload
# %autoreload 2
import os
import torch as t
from utils.config import opt
from model import FasterRCNNVGG16
from trainer import FasterRCNNTrainer
from data.util import  read_image
from utils.vis_tool import vis_bbox
from utils import array_tool as at
# %matplotlib inline

# %%
img = read_image('misc/demo.jpg')
img = t.from_numpy(img)[None]

# %%
faster_rcnn = FasterRCNNVGG16()
trainer = FasterRCNNTrainer(faster_rcnn).cuda()
# Out:
# Setting up a new session...
# Traceback (most recent call last):
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000017B07F0C7C8>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /env/faster-rcnn (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000017B07F0C7C8>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\visdom\__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\visdom\__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\requests\sessions.py", line 578, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Junmyeong Lee\anaconda3\envs\vision_tutorial\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /env/faster-rcnn (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000017B07F0C7C8>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
# Without the incoming socket you cannot receive events from the server or register event handlers to your Visdom client.
# Exception in user code:
# ------------------------------------------------------------

# %% [markdown]
# You'll need to download pretrained model from [google dirve](https://drive.google.com/open?id=1cQ27LIn-Rig4-Uayzy_gH5-cW-NRGVzY)
# # 1. model converted from chainer

# %%
# in this machine the cupy isn't install correctly... 
# so it's a little slow
trainer.load('chainer_best_model_converted_to_pytorch_0.7053.pth')
opt.caffe_pretrain=True # this model was trained from caffe-pretrained model
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
# it failed to find the dog, but if you set threshold from 0.7 to 0.6, you'll find it

# %% [markdown]
# # 2. model trained with torchvision pretrained model

# %%
trainer.load('fasterrcnn_12211511_0.701052458187_torchvision_pretrain.pth')
opt.caffe_pretrain=False # this model was trained from torchvision-pretrained model
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
# it failed to find the dog, but if you set threshold from 0.7 to 0.6, you'll find it

# %% [markdown]
# # 3. model trained with caffe pretrained model

# %%
trainer.load('fasterrcnn_12222105_0.712649824453_caffe_pretrain.pth')
opt.caffe_pretrain=True # this model was trained from caffe-pretrained model
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
